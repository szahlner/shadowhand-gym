# %% [markdown]
# # `shadowhand-gym` code example

# %% [markdown]
# ## Install `shadowhand-gym`
# You need to install `shadowhand-gym` from source for now.

# %%
# Download the repository
# !git clone https://github.com/szahlner/shadowhand-gym.git

# Install the module
# !pip install -e shadowhand-gym

# Set it as current directory
# %cd "shadowhand-gym"
# Out:
# Cloning into 'shadowhand-gym'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 227 (delta 87), reused 200 (delta 60), pack-reused 0
# Receiving objects: 100% (227/227), 11.72 MiB | 16.81 MiB/s, done.
# Resolving deltas: 100% (87/87), done.
# Obtaining file:///content/shadowhand-gym
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from shadowhand-gym==1.0.0) (0.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from shadowhand-gym==1.0.0) (1.19.5)
# Collecting pybullet
#   Downloading pybullet-3.1.7.tar.gz (79.0 MB)
#      |████████████████████████████████| 79.0 MB 31 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->shadowhand-gym==1.0.0) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->shadowhand-gym==1.0.0) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->shadowhand-gym==1.0.0) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->shadowhand-gym==1.0.0) (0.16.0)
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-3.1.7-cp37-cp37m-linux_x86_64.whl size=89751125 sha256=2cbc57be572bf69972bc25d19182d6145f9d761ab8396c26de4903ba9d918d36
#   Stored in directory: /root/.cache/pip/wheels/70/1c/62/86c8b68885c24123d87c5392d6678aa2b68a1796c8113e1aa6
# Successfully built pybullet
# Installing collected packages: pybullet, shadowhand-gym
#   Running setup.py develop for shadowhand-gym
# Successfully installed pybullet-3.1.7 shadowhand-gym-1.0.0
# /content/shadowhand-gym

# %% [markdown]
# ## Interact

# %%
import gym
import shadowhand_gym

env = gym.make("ShadowHandReach-v1")
state = env.reset()

done = False
images = [env.render("rgb_array")]
while not done:
    # Random action
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    images.append(env.render("rgb_array"))

env.close()

# %% [markdown]
# ## Convert and show an animation (apng)

# %%
# !pip3 install numpngw
from numpngw import write_apng
from IPython.display import Image

# Convert to apng
write_apng("animation.png", images, delay=40)

# Show animation
Image(filename="animation.png")
# Out:
# Collecting numpngw
#   Downloading numpngw-0.0.8-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from numpngw) (1.19.5)
# Installing collected packages: numpngw
# Successfully installed numpngw-0.0.8
